# %%
##################################################################################
#
#                         Arduino Interfacing with Python
#
##################################################################################

# %%
############################# Packages loading ###################################

import serial # require pip install PySerial for Serial communication
from tkinter import *
import tkinter as tk 
import time   #for delay functions

# %%
##################################################################################
# Basic Functions that represent the building blocks of the Program
##################################################################################

# %%
ser = serial.Serial('COM6', 9600)  # open serial port
time.sleep(2)                      # wait 2 seconds

# %%
turn_LED_ON = ser.write(b'H') # Turn ON the LED

# %%
turn_LED_OFF = ser.write(b'L') # Turn OFF the LED

# %%
############# Definition of the Functions ############################################

# %%
def turn_LED_ON():
    ser.write(b'H')

def turn_LED_OFF(): 
    ser.write(b'L')

# %%
################### Basic GUI based in tkinter #######################################

# %%
root = Tk()
root.wm_iconbitmap('C:/Users/renea/Pictures/Logos/gen_logo.ico')
root.wm_title('Name of the Company')
root.resizable(width=False, height=False)
root.geometry("370x130")

mainFrame = Frame(root, bd=10, bg='gainsboro',relief=RIDGE)
mainFrame.grid()

innerFrame = Frame(mainFrame, bd=5, bg='gainsboro', relief=RIDGE)
innerFrame.grid()

       # ##########################  Serial port configuration ###########################

ser = serial.Serial('COM6', 9600)  # open serial port
time.sleep(2)                      # wait 2 seconds

       ########################### Functions set ###########################

def turn_LED_ON():
    ser.write(b'H')

def turn_LED_OFF(): 
    ser.write(b'L')

        ###########################Buttons Widget###########################

btn_On = Button(innerFrame, text="LED ON", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=turn_LED_ON)
btn_On.grid(row=0,column = 0)

btn_Off = Button(innerFrame, text="LED OFF", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=turn_LED_OFF)
btn_Off.grid(row=0,column = 2)


root.mainloop()

# %%
#############################################################################################################################
#
#                        Demo Para probar la imagen del GUI LED
#
#############################################################################################################################


root = Tk()
root.wm_iconbitmap('C:/Users/renea/Pictures/Logos/CMF_logo.ico')
root.wm_title('Center of Molecular Fingerprinting (DEMO)')
root.resizable(width=False, height=False)
root.geometry("540x130")

mainFrame = Frame(root, bd=10, bg='gainsboro',relief=RIDGE)
mainFrame.grid()

innerFrame = Frame(mainFrame, bd=5, bg='gainsboro', relief=RIDGE)
innerFrame.grid()

       # ##########################  Serial port configuration ###########################

#ser = serial.Serial('COM5', 9600)  # open serial port
#time.sleep(2)                      # wait 2 seconds

       # ########################## Functions set ###########################

def turn_LED_ON():
    ser.write(b'H')

def turn_LED_OFF(): 
    ser.write(b'L')

        ###########################Buttons Widget###########################

btn_On = Button(innerFrame, text="LED ON", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro')
btn_On.grid(row=0,column = 0)

btn_On = Button(innerFrame, text="LED OFF", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro')
btn_On.grid(row=0,column = 1)

btn_Off = Button(innerFrame, text="Stop", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro')
btn_Off.grid(row=0,column = 2)

root.mainloop()

# %%
#############################################################################################################################
#
#                        Demo Para probar la imagen del GUI Stepper Motor
#
#############################################################################################################################


root = Tk()
root.wm_iconbitmap('C:/Users/renea/Pictures/Logos/CMF_logo.ico')
root.wm_title('Center of Molecular Fingerprinting (DEMO)')
root.resizable(width=False, height=False)
root.geometry("540x130")

mainFrame = Frame(root, bd=10, bg='gainsboro',relief=RIDGE)
mainFrame.grid()

innerFrame = Frame(mainFrame, bd=5, bg='gainsboro', relief=RIDGE)
innerFrame.grid()

       ###########################  Serial port configuration ###########################

#ser = serial.Serial('COM5', 9600)  # open serial port
#time.sleep(2)                      # wait 2 seconds

       ########################### Functions set ###########################

def turn_LED_ON():
    ser.write(b'H')

def turn_LED_OFF(): 
    ser.write(b'L')

        ###########################Buttons Widget###########################

btn_On = Button(innerFrame, text="<", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro')
btn_On.grid(row=0,column = 0)

btn_On = Button(innerFrame, text="Stop", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro')
btn_On.grid(row=0,column = 1)

btn_Off = Button(innerFrame, text=">", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro')
btn_Off.grid(row=0,column = 2)

root.mainloop()

# %%
#############################################################################################################################
#
#                        Demo Para probar la imagen del GUI Stepper Motor
#
#############################################################################################################################


root = Tk()
root.wm_iconbitmap('C:/Users/renea/Pictures/Logos/CMF_logo.ico')
root.wm_title('Center of Molecular Fingerprinting (DEMO)')
root.resizable(width=False, height=False)
root.geometry("540x300")

mainFrame = Frame(root, bd=10, bg='gainsboro',relief=RIDGE)
mainFrame.grid()

innerFrame = Frame(mainFrame, bd=5, bg='gainsboro', relief=RIDGE)
innerFrame.grid()

       ###########################  Serial port configuration ###########################

#ser = serial.Serial('COM5', 9600)  # open serial port
#time.sleep(2)                      # wait 2 seconds

       # ########################## Functions set ###########################

def X_right():
    ser.write(b'H')

def X_left(): 
    ser.write(b'L')

    
def Y_up():
    ser.write(b'H')

def Y_down(): 
    ser.write(b'L')
    
def Stop(): 
    ser.write(b'L')
    
    
def Z_up():
    ser.write(b'H')

def Z_down(): 
    ser.write(b'L')

        ###########################Buttons Widget###########################
        
########################## XY Control #################################

btn_On = Button(innerFrame, text="^", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=Y_up)
btn_On.grid(row=0,column = 1)        
        
btn_On = Button(innerFrame, text="<", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=X_left)
btn_On.grid(row=1,column = 0)

btn_On = Button(innerFrame, text="Stop", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=Stop)
btn_On.grid(row=1,column = 1)

btn_Off = Button(innerFrame, text=">", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=X_right)
btn_Off.grid(row=1,column = 2)

btn_On = Button(innerFrame, text="v", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=Y_down)
btn_On.grid(row=2,column = 1)  

############################ Z Cotrol ################################

#btn_On = Button(innerFrame, text="^", width=5, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=Z_up)
#btn_On.grid(row=0,column = 3)    

#btn_On = Button(innerFrame, text="v", width=5, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=Z_down)
#btn_On.grid(row=2,column = 3)

#btn_On = Button(innerFrame, text="Stop", width=5, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=Stop)
#btn_On.grid(row=1,column = 3)  

root.mainloop()
